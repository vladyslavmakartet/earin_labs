# %% [markdown]
# # 1. Import Dependencies

# %%
#Install SWIG https://sourceforge.net/projects/swig/files/swigwin/swigwin-4.0.2/swigwin-4.0.2.zip/download?use_mirror=ixpeering

# %%
# !pip install gym[box2d] pyglet==1.3.2

# %%
import gym 
from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import VecFrameStack, DummyVecEnv
from stable_baselines3.common.evaluation import evaluate_policy
import os

# %% [markdown]
# # 2. Test Environment

# %%
environment_name = "CarRacing-v0"

# %%
env = gym.make(environment_name)
# env = DummyVecEnv([lambda: env])

# %%
episodes = 20
for episode in range(1, episodes+1):
    state = env.reset()
    done = False
    score = 0 
    
    while not done:
        env.render()
        action = env.action_space.sample()
        n_state, reward, done, info = env.step(action)
        score+=reward
    print('Episode:{} Score:{}'.format(episode, score))
env.close()
# Out:
# Track generation: 1131..1418 -> 287-tiles track
# Episode:1 Score:-33.56643356643407
# Track generation: 1168..1464 -> 296-tiles track
# Episode:2 Score:-32.203389830508975
# Track generation: 1120..1407 -> 287-tiles track
# Episode:3 Score:-30.069930069930475
# Track generation: 1192..1494 -> 302-tiles track
# Episode:4 Score:-36.87707641196061
# Track generation: 1164..1459 -> 295-tiles track
# Episode:5 Score:-31.972789115646684
# Track generation: 1097..1381 -> 284-tiles track
# Episode:6 Score:-29.328621908127577
# Track generation: 1223..1538 -> 315-tiles track
# Episode:7 Score:-36.305732484077005
# Track generation: 1067..1341 -> 274-tiles track
# Episode:8 Score:-23.076923076923283
# Track generation: 1175..1473 -> 298-tiles track
# Episode:9 Score:-36.026936026936596
# Track generation: 950..1194 -> 244-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1148..1439 -> 291-tiles track
# Episode:10 Score:-31.034482758621127
# Track generation: 1124..1409 -> 285-tiles track
# Episode:11 Score:-33.098591549296216
# Track generation: 1193..1499 -> 306-tiles track
# Episode:12 Score:-34.42622950819717
# Track generation: 1240..1554 -> 314-tiles track
# Episode:13 Score:-39.297124600639606
# Track generation: 1208..1514 -> 306-tiles track
# Episode:14 Score:-34.42622950819722
# Track generation: 1010..1266 -> 256-tiles track
# Episode:15 Score:-21.56862745098053
# Track generation: 1304..1634 -> 330-tiles track
# Episode:16 Score:-39.209726443769625
# Track generation: 1156..1449 -> 293-tiles track
# Episode:17 Score:-31.50684931506891
# Track generation: 1293..1620 -> 327-tiles track
# Episode:18 Score:-38.650306748466896
# Track generation: 1214..1529 -> 315-tiles track
# Episode:19 Score:-39.49044585987321
# Track generation: 1051..1318 -> 267-tiles track
# Episode:20 Score:-28.57142857142893

# %%
env.close()

# %%
env.action_space.sample()
# Out:
# array([0.02317744, 0.68804586, 0.31200027], dtype=float32)

# %%
env.observation_space.sample()
# Out:
# array([[[223, 111, 227],
#         [120,  94,  34],
#         [ 60,  70,  28],
#         ...,
#         [ 23, 232, 167],
#         [184,   0, 115],
#         [ 84,  72,  57]],
#
#        [[171,  32, 196],
#         [ 43,  30, 136],
#         [ 78,  71, 224],
#         ...,
#         [112, 101,  13],
#         [ 52, 206,  64],
#         [ 61, 161,  82]],
#
#        [[246, 116, 208],
#         [221, 171, 118],
#         [137,  65,  39],
#         ...,
#         [189,  51, 139],
#         [131,  42, 243],
#         [217, 153,  10]],
#
#        ...,
#
#        [[210, 121, 149],
#         [251,  61, 119],
#         [168, 251, 211],
#         ...,
#         [ 62, 124, 109],
#         [253,  54, 224],
#         [225, 212,  71]],
#
#        [[110,  88,  98],
#         [170, 158, 127],
#         [208,  59, 202],
#         ...,
#         [164,  70,  28],
#         [159, 242,  37],
#         [178,  58, 214]],
#
#        [[ 20, 184,  79],
#         [ 85,  66, 121],
#         [173, 214,   4],
#         ...,
#         [  5, 246, 162],
#         [102, 108, 150],
#         [148,  24,  38]]], dtype=uint8)

# %% [markdown]
# # 3. Train Model

# %%
log_path = os.path.join('Training', 'Logs')

# %%
model = PPO("CnnPolicy", env, verbose=1, tensorboard_log=log_path)
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Wrapping the env in a VecTransposeImage.
# [W NNPACK.cpp:51] Could not initialize NNPACK! Reason: Unsupported hardware.

# %%
model.learn(total_timesteps=400000) # to try 256k
# Out:
# Track generation: 1226..1537 -> 311-tiles track
# Logging to Training/Logs/PPO_2
# Track generation: 1145..1436 -> 291-tiles track
# Track generation: 1135..1423 -> 288-tiles track
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | -54.9    |
# | time/              |          |
# |    fps             | 83       |
# |    iterations      | 1        |
# |    time_elapsed    | 24       |
# |    total_timesteps | 2048     |
# ---------------------------------
# Track generation: 1053..1319 -> 266-tiles track
# Track generation: 951..1198 -> 247-tiles track
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -52         |
# | time/                   |             |
# |    fps                  | 45          |
# |    iterations           | 2           |
# |    time_elapsed         | 90          |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.005322187 |
# |    clip_fraction        | 0.0468      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.24       |
# |    explained_variance   | -0.0122     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.298       |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.00429    |
# |    std                  | 0.993       |
# |    value_loss           | 0.645       |
# -----------------------------------------
# Track generation: 1120..1405 -> 285-tiles track
# Track generation: 1076..1356 -> 280-tiles track
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -51         |
# | time/                   |             |
# |    fps                  | 40          |
# |    iterations           | 3           |
# |    time_elapsed         | 152         |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.009863707 |
# |    clip_fraction        | 0.0724      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.21       |
# |    explained_variance   | 0.0282      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0679      |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.00878    |
# |    std                  | 0.979       |
# |    value_loss           | 0.584       |
# -----------------------------------------
# Track generation: 1239..1552 -> 313-tiles track
# Track generation: 1219..1528 -> 309-tiles track
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | -51.4        |
# | time/                   |              |
# |    fps                  | 38           |
# |    iterations           | 4            |
# |    time_elapsed         | 211          |
# |    total_timesteps      | 8192         |
# | train/                  |              |
# |    approx_kl            | 0.0074041085 |
# |    clip_fraction        | 0.0829       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.18        |
# |    explained_variance   | 0.193        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.298        |
# |    n_updates            | 30           |
# |    policy_gradient_loss | -0.00597     |
# |    std                  | 0.971        |
# |    value_loss           | 0.645        |
# ------------------------------------------
# Track generation: 1091..1368 -> 277-tiles track
# Track generation: 1064..1334 -> 270-tiles track
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -52.5       |
# | time/                   |             |
# |    fps                  | 37          |
# |    iterations           | 5           |
# |    time_elapsed         | 274         |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.011024287 |
# |    clip_fraction        | 0.123       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.16       |
# |    explained_variance   | 0.0584      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.171       |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0125     |
# |    std                  | 0.965       |
# |    value_loss           | 0.475       |
# -----------------------------------------
# Track generation: 1172..1475 -> 303-tiles track
# Track generation: 1147..1438 -> 291-tiles track
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | -53.1      |
# | time/                   |            |
# |    fps                  | 36         |
# |    iterations           | 6          |
# |    time_elapsed         | 336        |
# |    total_timesteps      | 12288      |
# | train/                  |            |
# |    approx_kl            | 0.01454802 |
# |    clip_fraction        | 0.142      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.14      |
# |    explained_variance   | 0.343      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0666     |
# |    n_updates            | 50         |
# |    policy_gradient_loss | -0.017     |
# |    std                  | 0.959      |
# |    value_loss           | 0.395      |
# ----------------------------------------
# Track generation: 1195..1497 -> 302-tiles track
# Track generation: 1163..1458 -> 295-tiles track
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -52.5       |
# | time/                   |             |
# |    fps                  | 35          |
# |    iterations           | 7           |
# |    time_elapsed         | 399         |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.008475708 |
# |    clip_fraction        | 0.107       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.1        |
# |    explained_variance   | 0.258       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0999      |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.0123     |
# |    std                  | 0.945       |
# |    value_loss           | 0.417       |
# -----------------------------------------
# Track generation: 1127..1413 -> 286-tiles track
# Track generation: 1053..1328 -> 275-tiles track
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -52.4       |
# | time/                   |             |
# |    fps                  | 35          |
# |    iterations           | 8           |
# |    time_elapsed         | 464         |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.014727389 |
# |    clip_fraction        | 0.135       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.08       |
# |    explained_variance   | 0.439       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.101       |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.0176     |
# |    std                  | 0.944       |
# |    value_loss           | 0.354       |
# -----------------------------------------
# Track generation: 995..1255 -> 260-tiles track
# Track generation: 1180..1479 -> 299-tiles track
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -51         |
# | time/                   |             |
# |    fps                  | 34          |
# |    iterations           | 9           |
# |    time_elapsed         | 532         |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.014394471 |
# |    clip_fraction        | 0.163       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.07       |
# |    explained_variance   | 0.471       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0563      |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.0182     |
# |    std                  | 0.938       |
# |    value_loss           | 0.289       |
# -----------------------------------------
# Track generation: 1299..1628 -> 329-tiles track
# Track generation: 1133..1420 -> 287-tiles track
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -50.2       |
# | time/                   |             |
# |    fps                  | 34          |
# |    iterations           | 10          |
# |    time_elapsed         | 597         |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.016782364 |
# |    clip_fraction        | 0.16        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.05       |
# |    explained_variance   | 0.51        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.121       |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.0231     |
# |    std                  | 0.928       |
# |    value_loss           | 0.395       |
# -----------------------------------------
# Track generation: 1135..1423 -> 288-tiles track
# Track generation: 1084..1359 -> 275-tiles track
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -48.8       |
# | time/                   |             |
# |    fps                  | 34          |
# |    iterations           | 11          |
# |    time_elapsed         | 658         |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.022490095 |
# |    clip_fraction        | 0.223       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.01       |
# |    explained_variance   | 0.518       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00125     |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.0291     |
# |    std                  | 0.916       |
# |    value_loss           | 0.297       |
# -----------------------------------------
# Track generation: 1199..1503 -> 304-tiles track
# Track generation: 1189..1490 -> 301-tiles track
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | -47.2      |
# | time/                   |            |
# |    fps                  | 34         |
# |    iterations           | 12         |
# |    time_elapsed         | 718        |
# |    total_timesteps      | 24576      |
# | train/                  |            |
# |    approx_kl            | 0.03039594 |
# |    clip_fraction        | 0.261      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.98      |
# |    explained_variance   | 0.523      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0249    |
# |    n_updates            | 110        |
# |    policy_gradient_loss | -0.0411    |
# |    std                  | 0.907      |
# |    value_loss           | 0.292      |
# ----------------------------------------
# Track generation: 1115..1398 -> 283-tiles track
# Track generation: 1088..1364 -> 276-tiles track
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | -46.2      |
# | time/                   |            |
# |    fps                  | 33         |
# |    iterations           | 13         |
# |    time_elapsed         | 788        |
# |    total_timesteps      | 26624      |
# | train/                  |            |
# |    approx_kl            | 0.03378409 |
# |    clip_fraction        | 0.28       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.95      |
# |    explained_variance   | 0.309      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0277    |
# |    n_updates            | 120        |
# |    policy_gradient_loss | -0.0343    |
# |    std                  | 0.899      |
# |    value_loss           | 0.28       |
# ----------------------------------------
# Track generation: 1193..1495 -> 302-tiles track
# Track generation: 1164..1459 -> 295-tiles track
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | -45.1      |
# | time/                   |            |
# |    fps                  | 33         |
# |    iterations           | 14         |
# |    time_elapsed         | 852        |
# |    total_timesteps      | 28672      |
# | train/                  |            |
# |    approx_kl            | 0.04218954 |
# |    clip_fraction        | 0.299      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.91      |
# |    explained_variance   | 0.424      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0307     |
# |    n_updates            | 130        |
# |    policy_gradient_loss | -0.047     |
# |    std                  | 0.884      |
# |    value_loss           | 0.276      |
# ----------------------------------------
# Track generation: 1299..1628 -> 329-tiles track
# Track generation: 1101..1387 -> 286-tiles track
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | -44.8      |
# | time/                   |            |
# |    fps                  | 33         |
# |    iterations           | 15         |
# |    time_elapsed         | 915        |
# |    total_timesteps      | 30720      |
# | train/                  |            |
# |    approx_kl            | 0.05088806 |
# |    clip_fraction        | 0.353      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.87      |
# |    explained_variance   | 0.21       |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.00919   |
# |    n_updates            | 140        |
# |    policy_gradient_loss | -0.0459    |
# |    std                  | 0.876      |
# |    value_loss           | 0.254      |
# ----------------------------------------
# Track generation: 1040..1304 -> 264-tiles track
# Track generation: 1187..1488 -> 301-tiles track
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -42.5       |
# | time/                   |             |
# |    fps                  | 33          |
# |    iterations           | 16          |
# |    time_elapsed         | 977         |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.045961052 |
# |    clip_fraction        | 0.349       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.85       |
# |    explained_variance   | 0.418       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00687    |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.046      |
# |    std                  | 0.872       |
# |    value_loss           | 0.251       |
# -----------------------------------------
# Track generation: 1120..1404 -> 284-tiles track
# Track generation: 1086..1361 -> 275-tiles track
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | -40.8      |
# | time/                   |            |
# |    fps                  | 33         |
# |    iterations           | 17         |
# |    time_elapsed         | 1038       |
# |    total_timesteps      | 34816      |
# | train/                  |            |
# |    approx_kl            | 0.04415901 |
# |    clip_fraction        | 0.342      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.82      |
# |    explained_variance   | 0.66       |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0261     |
# |    n_updates            | 160        |
# |    policy_gradient_loss | -0.0379    |
# |    std                  | 0.861      |
# |    value_loss           | 0.357      |
# ----------------------------------------
# Track generation: 1140..1429 -> 289-tiles track
# Track generation: 1088..1371 -> 283-tiles track
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -39.1       |
# | time/                   |             |
# |    fps                  | 33          |
# |    iterations           | 18          |
# |    time_elapsed         | 1101        |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.055392995 |
# |    clip_fraction        | 0.375       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.78       |
# |    explained_variance   | 0.704       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0244     |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.0469     |
# |    std                  | 0.852       |
# |    value_loss           | 0.293       |
# -----------------------------------------
# Track generation: 1161..1454 -> 293-tiles track
# Track generation: 1188..1489 -> 301-tiles track
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -38.5       |
# | time/                   |             |
# |    fps                  | 33          |
# |    iterations           | 19          |
# |    time_elapsed         | 1163        |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.040110223 |
# |    clip_fraction        | 0.308       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.74       |
# |    explained_variance   | 0.704       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0401     |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.0362     |
# |    std                  | 0.835       |
# |    value_loss           | 0.341       |
# -----------------------------------------
# Track generation: 1018..1278 -> 260-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1109..1395 -> 286-tiles track
# Track generation: 1050..1317 -> 267-tiles track
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -36.7       |
# | time/                   |             |
# |    fps                  | 33          |
# |    iterations           | 20          |
# |    time_elapsed         | 1225        |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.060350366 |
# |    clip_fraction        | 0.373       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.68       |
# |    explained_variance   | 0.788       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0343     |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.046      |
# |    std                  | 0.818       |
# |    value_loss           | 0.252       |
# -----------------------------------------
# Track generation: 1198..1508 -> 310-tiles track
# Track generation: 1122..1406 -> 284-tiles track
# Track generation: 1127..1415 -> 288-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1263..1583 -> 320-tiles track
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -34.6       |
# | time/                   |             |
# |    fps                  | 33          |
# |    iterations           | 21          |
# |    time_elapsed         | 1286        |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.052568346 |
# |    clip_fraction        | 0.373       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.62       |
# |    explained_variance   | 0.863       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0278     |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.0442     |
# |    std                  | 0.802       |
# |    value_loss           | 0.327       |
# -----------------------------------------
# Track generation: 1265..1585 -> 320-tiles track
# Track generation: 1145..1440 -> 295-tiles track
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -34.3       |
# | time/                   |             |
# |    fps                  | 33          |
# |    iterations           | 22          |
# |    time_elapsed         | 1348        |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.049970895 |
# |    clip_fraction        | 0.348       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.56       |
# |    explained_variance   | 0.899       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0204     |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.0475     |
# |    std                  | 0.787       |
# |    value_loss           | 0.223       |
# -----------------------------------------
# Track generation: 1117..1400 -> 283-tiles track
# Track generation: 1067..1338 -> 271-tiles track
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | -34.2      |
# | time/                   |            |
# |    fps                  | 33         |
# |    iterations           | 23         |
# |    time_elapsed         | 1410       |
# |    total_timesteps      | 47104      |
# | train/                  |            |
# |    approx_kl            | 0.06909756 |
# |    clip_fraction        | 0.41       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.52      |
# |    explained_variance   | 0.93       |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.00864    |
# |    n_updates            | 220        |
# |    policy_gradient_loss | -0.0472    |
# |    std                  | 0.779      |
# |    value_loss           | 0.175      |
# ----------------------------------------
# Track generation: 1200..1504 -> 304-tiles track
# Track generation: 1226..1543 -> 317-tiles track
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | -33.6      |
# | time/                   |            |
# |    fps                  | 33         |
# |    iterations           | 24         |
# |    time_elapsed         | 1470       |
# |    total_timesteps      | 49152      |
# | train/                  |            |
# |    approx_kl            | 0.05434607 |
# |    clip_fraction        | 0.365      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.47      |
# |    explained_variance   | 0.933      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0524    |
# |    n_updates            | 230        |
# |    policy_gradient_loss | -0.0434    |
# |    std                  | 0.765      |
# |    value_loss           | 0.191      |
# ----------------------------------------
# Track generation: 1227..1538 -> 311-tiles track
# Track generation: 1104..1384 -> 280-tiles track
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -34         |
# | time/                   |             |
# |    fps                  | 33          |
# |    iterations           | 25          |
# |    time_elapsed         | 1538        |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.062328625 |
# |    clip_fraction        | 0.37        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.41       |
# |    explained_variance   | 0.942       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0371     |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.0486     |
# |    std                  | 0.751       |
# |    value_loss           | 0.203       |
# -----------------------------------------
# Track generation: 1152..1444 -> 292-tiles track
# Track generation: 977..1234 -> 257-tiles track
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | -33.2      |
# | time/                   |            |
# |    fps                  | 33         |
# |    iterations           | 26         |
# |    time_elapsed         | 1602       |
# |    total_timesteps      | 53248      |
# | train/                  |            |
# |    approx_kl            | 0.05616757 |
# |    clip_fraction        | 0.368      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.37      |
# |    explained_variance   | 0.943      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0556    |
# |    n_updates            | 250        |
# |    policy_gradient_loss | -0.0388    |
# |    std                  | 0.743      |
# |    value_loss           | 0.145      |
# ----------------------------------------
# Track generation: 1095..1373 -> 278-tiles track
# Track generation: 1064..1334 -> 270-tiles track
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -33         |
# | time/                   |             |
# |    fps                  | 33          |
# |    iterations           | 27          |
# |    time_elapsed         | 1666        |
# |    total_timesteps      | 55296       |
# | train/                  |             |
# |    approx_kl            | 0.047001764 |
# |    clip_fraction        | 0.346       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.34       |
# |    explained_variance   | 0.902       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0387     |
# |    n_updates            | 260         |
# |    policy_gradient_loss | -0.0383     |
# |    std                  | 0.738       |
# |    value_loss           | 0.276       |
# -----------------------------------------
# Track generation: 1069..1340 -> 271-tiles track
# Track generation: 1140..1429 -> 289-tiles track
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -32.7       |
# | time/                   |             |
# |    fps                  | 33          |
# |    iterations           | 28          |
# |    time_elapsed         | 1728        |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.069248155 |
# |    clip_fraction        | 0.399       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.31       |
# |    explained_variance   | 0.973       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0306     |
# |    n_updates            | 270         |
# |    policy_gradient_loss | -0.0427     |
# |    std                  | 0.725       |
# |    value_loss           | 0.19        |
# -----------------------------------------
# Track generation: 1203..1508 -> 305-tiles track
# Track generation: 1047..1313 -> 266-tiles track
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | -32.7      |
# | time/                   |            |
# |    fps                  | 33         |
# |    iterations           | 29         |
# |    time_elapsed         | 1793       |
# |    total_timesteps      | 59392      |
# | train/                  |            |
# |    approx_kl            | 0.06122023 |
# |    clip_fraction        | 0.353      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.26      |
# |    explained_variance   | 0.968      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.00753   |
# |    n_updates            | 280        |
# |    policy_gradient_loss | -0.0444    |
# |    std                  | 0.72       |
# |    value_loss           | 0.223      |
# ----------------------------------------
# Track generation: 1221..1530 -> 309-tiles track
# Track generation: 1099..1378 -> 279-tiles track
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | -32.4      |
# | time/                   |            |
# |    fps                  | 33         |
# |    iterations           | 30         |
# |    time_elapsed         | 1857       |
# |    total_timesteps      | 61440      |
# | train/                  |            |
# |    approx_kl            | 0.07867228 |
# |    clip_fraction        | 0.368      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.24      |
# |    explained_variance   | 0.973      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0422    |
# |    n_updates            | 290        |
# |    policy_gradient_loss | -0.0378    |
# |    std                  | 0.712      |
# |    value_loss           | 0.165      |
# ----------------------------------------
# Track generation: 1152..1444 -> 292-tiles track
# Track generation: 1150..1441 -> 291-tiles track
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -31.6       |
# | time/                   |             |
# |    fps                  | 32          |
# |    iterations           | 31          |
# |    time_elapsed         | 1927        |
# |    total_timesteps      | 63488       |
# | train/                  |             |
# |    approx_kl            | 0.048696093 |
# |    clip_fraction        | 0.365       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.22       |
# |    explained_variance   | 0.967       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00523    |
# |    n_updates            | 300         |
# |    policy_gradient_loss | -0.0347     |
# |    std                  | 0.71        |
# |    value_loss           | 0.345       |
# -----------------------------------------
# Track generation: 1211..1518 -> 307-tiles track
# Track generation: 1215..1523 -> 308-tiles track
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -31.2       |
# | time/                   |             |
# |    fps                  | 32          |
# |    iterations           | 32          |
# |    time_elapsed         | 1992        |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.047796674 |
# |    clip_fraction        | 0.34        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.2        |
# |    explained_variance   | 0.983       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0418      |
# |    n_updates            | 310         |
# |    policy_gradient_loss | -0.0403     |
# |    std                  | 0.701       |
# |    value_loss           | 0.255       |
# -----------------------------------------
# Track generation: 1182..1487 -> 305-tiles track
# Track generation: 1063..1335 -> 272-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1137..1425 -> 288-tiles track
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | -29.9      |
# | time/                   |            |
# |    fps                  | 32         |
# |    iterations           | 33         |
# |    time_elapsed         | 2059       |
# |    total_timesteps      | 67584      |
# | train/                  |            |
# |    approx_kl            | 0.07478887 |
# |    clip_fraction        | 0.361      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.16      |
# |    explained_variance   | 0.987      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.00553   |
# |    n_updates            | 320        |
# |    policy_gradient_loss | -0.0494    |
# |    std                  | 0.692      |
# |    value_loss           | 0.201      |
# ----------------------------------------
# Track generation: 1307..1638 -> 331-tiles track
# Track generation: 1134..1422 -> 288-tiles track
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -29.7       |
# | time/                   |             |
# |    fps                  | 32          |
# |    iterations           | 34          |
# |    time_elapsed         | 2126        |
# |    total_timesteps      | 69632       |
# | train/                  |             |
# |    approx_kl            | 0.054501504 |
# |    clip_fraction        | 0.369       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.11       |
# |    explained_variance   | 0.977       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0439     |
# |    n_updates            | 330         |
# |    policy_gradient_loss | -0.0419     |
# |    std                  | 0.682       |
# |    value_loss           | 0.281       |
# -----------------------------------------
# Track generation: 1111..1393 -> 282-tiles track
# Track generation: 1161..1463 -> 302-tiles track
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | -29.7      |
# | time/                   |            |
# |    fps                  | 32         |
# |    iterations           | 35         |
# |    time_elapsed         | 2197       |
# |    total_timesteps      | 71680      |
# | train/                  |            |
# |    approx_kl            | 0.06221178 |
# |    clip_fraction        | 0.351      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.08      |
# |    explained_variance   | 0.985      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0277     |
# |    n_updates            | 340        |
# |    policy_gradient_loss | -0.0363    |
# |    std                  | 0.675      |
# |    value_loss           | 0.233      |
# ----------------------------------------
# Track generation: 1125..1407 -> 282-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1056..1324 -> 268-tiles track
# Track generation: 1253..1571 -> 318-tiles track
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | -28.5      |
# | time/                   |            |
# |    fps                  | 32         |
# |    iterations           | 36         |
# |    time_elapsed         | 2253       |
# |    total_timesteps      | 73728      |
# | train/                  |            |
# |    approx_kl            | 0.06659537 |
# |    clip_fraction        | 0.365      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.01      |
# |    explained_variance   | 0.977      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.026     |
# |    n_updates            | 350        |
# |    policy_gradient_loss | -0.0338    |
# |    std                  | 0.656      |
# |    value_loss           | 0.177      |
# ----------------------------------------
# Track generation: 1175..1473 -> 298-tiles track
# Track generation: 1155..1448 -> 293-tiles track
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | -28.3      |
# | time/                   |            |
# |    fps                  | 32         |
# |    iterations           | 37         |
# |    time_elapsed         | 2312       |
# |    total_timesteps      | 75776      |
# | train/                  |            |
# |    approx_kl            | 0.08774905 |
# |    clip_fraction        | 0.414      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.96      |
# |    explained_variance   | 0.971      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0333    |
# |    n_updates            | 360        |
# |    policy_gradient_loss | -0.0425    |
# |    std                  | 0.649      |
# |    value_loss           | 0.371      |
# ----------------------------------------
# Track generation: 1070..1346 -> 276-tiles track
# Track generation: 1158..1451 -> 293-tiles track
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -25.4       |
# | time/                   |             |
# |    fps                  | 32          |
# |    iterations           | 38          |
# |    time_elapsed         | 2372        |
# |    total_timesteps      | 77824       |
# | train/                  |             |
# |    approx_kl            | 0.067543134 |
# |    clip_fraction        | 0.408       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.93       |
# |    explained_variance   | 0.988       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0337     |
# |    n_updates            | 370         |
# |    policy_gradient_loss | -0.0437     |
# |    std                  | 0.645       |
# |    value_loss           | 0.225       |
# -----------------------------------------
# Track generation: 1155..1451 -> 296-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1235..1548 -> 313-tiles track
# Track generation: 1259..1578 -> 319-tiles track
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -24.1       |
# | time/                   |             |
# |    fps                  | 32          |
# |    iterations           | 39          |
# |    time_elapsed         | 2433        |
# |    total_timesteps      | 79872       |
# | train/                  |             |
# |    approx_kl            | 0.054655265 |
# |    clip_fraction        | 0.381       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.89       |
# |    explained_variance   | 0.944       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0217      |
# |    n_updates            | 380         |
# |    policy_gradient_loss | -0.0431     |
# |    std                  | 0.636       |
# |    value_loss           | 0.719       |
# -----------------------------------------
# Track generation: 1472..1844 -> 372-tiles track
# Track generation: 1163..1458 -> 295-tiles track
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -21         |
# | time/                   |             |
# |    fps                  | 32          |
# |    iterations           | 40          |
# |    time_elapsed         | 2495        |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.082950585 |
# |    clip_fraction        | 0.393       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.85       |
# |    explained_variance   | 0.975       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00181     |
# |    n_updates            | 390         |
# |    policy_gradient_loss | -0.0338     |
# |    std                  | 0.624       |
# |    value_loss           | 0.196       |
# -----------------------------------------
# Track generation: 1103..1383 -> 280-tiles track
# Track generation: 1328..1665 -> 337-tiles track
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | -12.4      |
# | time/                   |            |
# |    fps                  | 32         |
# |    iterations           | 41         |
# |    time_elapsed         | 2556       |
# |    total_timesteps      | 83968      |
# | train/                  |            |
# |    approx_kl            | 0.07319495 |
# |    clip_fraction        | 0.451      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.81      |
# |    explained_variance   | 0.787      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.193      |
# |    n_updates            | 400        |
# |    policy_gradient_loss | -0.0258    |
# |    std                  | 0.621      |
# |    value_loss           | 2.37       |
# ----------------------------------------
# Track generation: 1003..1258 -> 255-tiles track
# Track generation: 987..1240 -> 253-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 988..1242 -> 254-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1308..1639 -> 331-tiles track
# Track generation: 1215..1523 -> 308-tiles track
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -5.1        |
# | time/                   |             |
# |    fps                  | 32          |
# |    iterations           | 42          |
# |    time_elapsed         | 2616        |
# |    total_timesteps      | 86016       |
# | train/                  |             |
# |    approx_kl            | 0.104542166 |
# |    clip_fraction        | 0.497       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.79       |
# |    explained_variance   | 0.806       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.232       |
# |    n_updates            | 410         |
# |    policy_gradient_loss | -0.0312     |
# |    std                  | 0.616       |
# |    value_loss           | 2.13        |
# -----------------------------------------
# Track generation: 1159..1453 -> 294-tiles track
# Track generation: 1370..1717 -> 347-tiles track
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | 3.49       |
# | time/                   |            |
# |    fps                  | 32         |
# |    iterations           | 43         |
# |    time_elapsed         | 2677       |
# |    total_timesteps      | 88064      |
# | train/                  |            |
# |    approx_kl            | 0.07961236 |
# |    clip_fraction        | 0.433      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.77      |
# |    explained_variance   | 0.929      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.252      |
# |    n_updates            | 420        |
# |    policy_gradient_loss | -0.0187    |
# |    std                  | 0.615      |
# |    value_loss           | 2.21       |
# ----------------------------------------
# Track generation: 959..1203 -> 244-tiles track
# Track generation: 1059..1328 -> 269-tiles track
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | 8.95       |
# | time/                   |            |
# |    fps                  | 32         |
# |    iterations           | 44         |
# |    time_elapsed         | 2738       |
# |    total_timesteps      | 90112      |
# | train/                  |            |
# |    approx_kl            | 0.09758325 |
# |    clip_fraction        | 0.498      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.76      |
# |    explained_variance   | 0.845      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.531      |
# |    n_updates            | 430        |
# |    policy_gradient_loss | -0.0231    |
# |    std                  | 0.612      |
# |    value_loss           | 3.14       |
# ----------------------------------------
# Track generation: 1092..1369 -> 277-tiles track
# Track generation: 1218..1534 -> 316-tiles track
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 14.4        |
# | time/                   |             |
# |    fps                  | 32          |
# |    iterations           | 45          |
# |    time_elapsed         | 2797        |
# |    total_timesteps      | 92160       |
# | train/                  |             |
# |    approx_kl            | 0.092159964 |
# |    clip_fraction        | 0.451       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.75       |
# |    explained_variance   | 0.917       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.961       |
# |    n_updates            | 440         |
# |    policy_gradient_loss | -0.00287    |
# |    std                  | 0.61        |
# |    value_loss           | 3.64        |
# -----------------------------------------
# Track generation: 1060..1329 -> 269-tiles track
# Track generation: 1156..1449 -> 293-tiles track
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 19.5        |
# | time/                   |             |
# |    fps                  | 32          |
# |    iterations           | 46          |
# |    time_elapsed         | 2858        |
# |    total_timesteps      | 94208       |
# | train/                  |             |
# |    approx_kl            | 0.086909376 |
# |    clip_fraction        | 0.49        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.74       |
# |    explained_variance   | 0.904       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.923       |
# |    n_updates            | 450         |
# |    policy_gradient_loss | -0.00408    |
# |    std                  | 0.61        |
# |    value_loss           | 5.44        |
# -----------------------------------------
# Track generation: 1156..1449 -> 293-tiles track
# Track generation: 1091..1374 -> 283-tiles track
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 26.4        |
# | time/                   |             |
# |    fps                  | 32          |
# |    iterations           | 47          |
# |    time_elapsed         | 2922        |
# |    total_timesteps      | 96256       |
# | train/                  |             |
# |    approx_kl            | 0.119340315 |
# |    clip_fraction        | 0.529       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.74       |
# |    explained_variance   | 0.9         |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.814       |
# |    n_updates            | 460         |
# |    policy_gradient_loss | 0.00473     |
# |    std                  | 0.609       |
# ...
# |    iterations           | 181        |
# |    time_elapsed         | 11144      |
# |    total_timesteps      | 370688     |
# | train/                  |            |
# |    approx_kl            | 0.18427296 |
# |    clip_fraction        | 0.442      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.38      |
# |    explained_variance   | 0.981      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0826     |
# |    n_updates            | 1800       |
# |    policy_gradient_loss | -0.00711   |
# |    std                  | 0.543      |
# |    value_loss           | 1.17       |
# ----------------------------------------
# Track generation: 1172..1469 -> 297-tiles track
# Track generation: 1072..1344 -> 272-tiles track
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 977        |
# |    ep_rew_mean          | 284        |
# | time/                   |            |
# |    fps                  | 33         |
# |    iterations           | 182        |
# |    time_elapsed         | 11197      |
# |    total_timesteps      | 372736     |
# | train/                  |            |
# |    approx_kl            | 0.19761649 |
# |    clip_fraction        | 0.556      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.38      |
# |    explained_variance   | 0.967      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.355      |
# |    n_updates            | 1810       |
# |    policy_gradient_loss | 0.0244     |
# |    std                  | 0.543      |
# |    value_loss           | 4.21       |
# ----------------------------------------
# Track generation: 1155..1448 -> 293-tiles track
# Track generation: 1141..1438 -> 297-tiles track
# Track generation: 1041..1308 -> 267-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 954..1201 -> 247-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1024..1284 -> 260-tiles track
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 969       |
# |    ep_rew_mean          | 275       |
# | time/                   |           |
# |    fps                  | 33        |
# |    iterations           | 183       |
# |    time_elapsed         | 11251     |
# |    total_timesteps      | 374784    |
# | train/                  |           |
# |    approx_kl            | 0.4591387 |
# |    clip_fraction        | 0.497     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -2.38     |
# |    explained_variance   | 0.95      |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.191     |
# |    n_updates            | 1820      |
# |    policy_gradient_loss | 0.0016    |
# |    std                  | 0.541     |
# |    value_loss           | 5.23      |
# ---------------------------------------
# Track generation: 1231..1543 -> 312-tiles track
# Track generation: 1176..1474 -> 298-tiles track
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 969       |
# |    ep_rew_mean          | 269       |
# | time/                   |           |
# |    fps                  | 33        |
# |    iterations           | 184       |
# |    time_elapsed         | 11303     |
# |    total_timesteps      | 376832    |
# | train/                  |           |
# |    approx_kl            | 0.9783686 |
# |    clip_fraction        | 0.547     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -2.37     |
# |    explained_variance   | 0.924     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.374     |
# |    n_updates            | 1830      |
# |    policy_gradient_loss | 0.00964   |
# |    std                  | 0.54      |
# |    value_loss           | 8.43      |
# ---------------------------------------
# Track generation: 1218..1534 -> 316-tiles track
# Track generation: 1203..1508 -> 305-tiles track
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 973       |
# |    ep_rew_mean          | 265       |
# | time/                   |           |
# |    fps                  | 33        |
# |    iterations           | 185       |
# |    time_elapsed         | 11359     |
# |    total_timesteps      | 378880    |
# | train/                  |           |
# |    approx_kl            | 0.8330921 |
# |    clip_fraction        | 0.493     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -2.35     |
# |    explained_variance   | 0.902     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.0694    |
# |    n_updates            | 1840      |
# |    policy_gradient_loss | -0.0143   |
# |    std                  | 0.534     |
# |    value_loss           | 1.49      |
# ---------------------------------------
# Track generation: 1212..1519 -> 307-tiles track
# Track generation: 960..1211 -> 251-tiles track
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 973        |
# |    ep_rew_mean          | 260        |
# | time/                   |            |
# |    fps                  | 33         |
# |    iterations           | 186        |
# |    time_elapsed         | 11413      |
# |    total_timesteps      | 380928     |
# | train/                  |            |
# |    approx_kl            | 0.21114922 |
# |    clip_fraction        | 0.493      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.32      |
# |    explained_variance   | 0.962      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.00914    |
# |    n_updates            | 1850       |
# |    policy_gradient_loss | -0.012     |
# |    std                  | 0.528      |
# |    value_loss           | 0.861      |
# ----------------------------------------
# Track generation: 1164..1459 -> 295-tiles track
# Track generation: 1312..1644 -> 332-tiles track
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 973        |
# |    ep_rew_mean          | 256        |
# | time/                   |            |
# |    fps                  | 33         |
# |    iterations           | 187        |
# |    time_elapsed         | 11470      |
# |    total_timesteps      | 382976     |
# | train/                  |            |
# |    approx_kl            | 0.16937786 |
# |    clip_fraction        | 0.514      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.3       |
# |    explained_variance   | 0.893      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.229      |
# |    n_updates            | 1860       |
# |    policy_gradient_loss | 0.00156    |
# |    std                  | 0.53       |
# |    value_loss           | 2.53       |
# ----------------------------------------
# Track generation: 976..1230 -> 254-tiles track
# Track generation: 1192..1494 -> 302-tiles track
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 979        |
# |    ep_rew_mean          | 253        |
# | time/                   |            |
# |    fps                  | 33         |
# |    iterations           | 188        |
# |    time_elapsed         | 11524      |
# |    total_timesteps      | 385024     |
# | train/                  |            |
# |    approx_kl            | 0.20818275 |
# |    clip_fraction        | 0.537      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.31      |
# |    explained_variance   | 0.906      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.323      |
# |    n_updates            | 1870       |
# |    policy_gradient_loss | -0.0107    |
# |    std                  | 0.528      |
# |    value_loss           | 2.44       |
# ----------------------------------------
# Track generation: 1135..1425 -> 290-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1080..1360 -> 280-tiles track
# Track generation: 1259..1578 -> 319-tiles track
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 979        |
# |    ep_rew_mean          | 248        |
# | time/                   |            |
# |    fps                  | 33         |
# |    iterations           | 189        |
# |    time_elapsed         | 11578      |
# |    total_timesteps      | 387072     |
# | train/                  |            |
# |    approx_kl            | 0.24195254 |
# |    clip_fraction        | 0.537      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.3       |
# |    explained_variance   | 0.934      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.146      |
# |    n_updates            | 1880       |
# |    policy_gradient_loss | 0.000139   |
# |    std                  | 0.529      |
# |    value_loss           | 1.54       |
# ----------------------------------------
# Track generation: 1143..1433 -> 290-tiles track
# Track generation: 1159..1453 -> 294-tiles track
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 979        |
# |    ep_rew_mean          | 240        |
# | time/                   |            |
# |    fps                  | 33         |
# |    iterations           | 190        |
# |    time_elapsed         | 11634      |
# |    total_timesteps      | 389120     |
# | train/                  |            |
# |    approx_kl            | 0.17086771 |
# |    clip_fraction        | 0.472      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.3       |
# |    explained_variance   | 0.938      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0498     |
# |    n_updates            | 1890       |
# |    policy_gradient_loss | -0.00911   |
# |    std                  | 0.526      |
# |    value_loss           | 1.12       |
# ----------------------------------------
# Track generation: 1215..1526 -> 311-tiles track
# Track generation: 1097..1382 -> 285-tiles track
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 979        |
# |    ep_rew_mean          | 232        |
# | time/                   |            |
# |    fps                  | 33         |
# |    iterations           | 191        |
# |    time_elapsed         | 11688      |
# |    total_timesteps      | 391168     |
# | train/                  |            |
# |    approx_kl            | 0.25665706 |
# |    clip_fraction        | 0.514      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.28      |
# |    explained_variance   | 0.868      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.00143    |
# |    n_updates            | 1900       |
# |    policy_gradient_loss | -0.0162    |
# |    std                  | 0.521      |
# |    value_loss           | 1.04       |
# ----------------------------------------
# Track generation: 1037..1300 -> 263-tiles track
# Track generation: 1144..1434 -> 290-tiles track
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 979        |
# |    ep_rew_mean          | 223        |
# | time/                   |            |
# |    fps                  | 33         |
# |    iterations           | 192        |
# |    time_elapsed         | 11743      |
# |    total_timesteps      | 393216     |
# | train/                  |            |
# |    approx_kl            | 0.14381972 |
# |    clip_fraction        | 0.462      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.26      |
# |    explained_variance   | 0.919      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0723     |
# |    n_updates            | 1910       |
# |    policy_gradient_loss | -0.00265   |
# |    std                  | 0.522      |
# |    value_loss           | 0.885      |
# ----------------------------------------
# Track generation: 1120..1404 -> 284-tiles track
# Track generation: 1146..1437 -> 291-tiles track
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 984        |
# |    ep_rew_mean          | 220        |
# | time/                   |            |
# |    fps                  | 33         |
# |    iterations           | 193        |
# |    time_elapsed         | 11798      |
# |    total_timesteps      | 395264     |
# | train/                  |            |
# |    approx_kl            | 0.13822973 |
# |    clip_fraction        | 0.454      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.25      |
# |    explained_variance   | 0.925      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0168    |
# |    n_updates            | 1920       |
# |    policy_gradient_loss | -0.0149    |
# |    std                  | 0.517      |
# |    value_loss           | 1.39       |
# ----------------------------------------
# Track generation: 1236..1549 -> 313-tiles track
# Track generation: 1050..1320 -> 270-tiles track
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 984        |
# |    ep_rew_mean          | 205        |
# | time/                   |            |
# |    fps                  | 33         |
# |    iterations           | 194        |
# |    time_elapsed         | 11855      |
# |    total_timesteps      | 397312     |
# | train/                  |            |
# |    approx_kl            | 0.18495354 |
# |    clip_fraction        | 0.467      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.23      |
# |    explained_variance   | 0.917      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0675     |
# |    n_updates            | 1930       |
# |    policy_gradient_loss | -0.00857   |
# |    std                  | 0.516      |
# |    value_loss           | 1.24       |
# ----------------------------------------
# Track generation: 1164..1459 -> 295-tiles track
# Track generation: 1295..1623 -> 328-tiles track
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 984        |
# |    ep_rew_mean          | 195        |
# | time/                   |            |
# |    fps                  | 33         |
# |    iterations           | 195        |
# |    time_elapsed         | 11926      |
# |    total_timesteps      | 399360     |
# | train/                  |            |
# |    approx_kl            | 0.23316815 |
# |    clip_fraction        | 0.502      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.23      |
# |    explained_variance   | 0.912      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0534     |
# |    n_updates            | 1940       |
# |    policy_gradient_loss | -0.00281   |
# |    std                  | 0.515      |
# |    value_loss           | 1.85       |
# ----------------------------------------
# Track generation: 1070..1342 -> 272-tiles track
# Track generation: 1179..1478 -> 299-tiles track
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 984        |
# |    ep_rew_mean          | 186        |
# | time/                   |            |
# |    fps                  | 33         |
# |    iterations           | 196        |
# |    time_elapsed         | 11999      |
# |    total_timesteps      | 401408     |
# | train/                  |            |
# |    approx_kl            | 0.18695742 |
# |    clip_fraction        | 0.514      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.22      |
# |    explained_variance   | 0.879      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.109      |
# |    n_updates            | 1950       |
# |    policy_gradient_loss | -0.00155   |
# |    std                  | 0.513      |
# |    value_loss           | 3.36       |
# ----------------------------------------

# %% [markdown]
# # 4. Save Model

# %%
ppo_path = os.path.join('Training', 'Saved Models', 'PPO_Driving_model')

# %%
model.save(ppo_path)

# %% [markdown]
# # 5. Evaluate and Test

# %%
print(evaluate_policy(model, env, n_eval_episodes=10, render=True))
# Out:
# Track generation: 1308..1639 -> 331-tiles track
# Track generation: 1072..1344 -> 272-tiles track
# Track generation: 1440..1804 -> 364-tiles track
# Track generation: 1152..1444 -> 292-tiles track
# Track generation: 1132..1419 -> 287-tiles track
# Track generation: 1006..1270 -> 264-tiles track
# Track generation: 1140..1429 -> 289-tiles track
# Track generation: 1162..1456 -> 294-tiles track
# Track generation: 1208..1514 -> 306-tiles track
# Track generation: 1181..1489 -> 308-tiles track
# Track generation: 1149..1440 -> 291-tiles track
# (47.543269857764244, 124.91550311590863)

# %%
env.close()

# %%
obs = env.reset()
while True:
    action, _states = model.predict(obs.copy())
    obs, rewards, dones, info = env.step(action)
    env.render()

# %%
env.close()
